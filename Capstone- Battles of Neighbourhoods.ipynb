# %% [markdown]
# # <center> Capstone Project: Battles of Neighbourhoods<center>

# %% [markdown]
# ### I. Description of the business problem and discussion of the background

# %% [markdown]
# An acclaimed chef is looking to open an Asian restaurant in Toronto city of Cananda. The chef has been in the restaurant industry for his entire life and is widely acclaimed for his culinary expertise and success in the restaurant industry in Asia. The chef is now looking to expand his restaurant business into Toronto. The new business venture will be a high-end culinary establishment that targets middle-income and well-off diners.

# %%
import numpy as np 
import imageio
import matplotlib.pyplot as plt
from PIL import Image
im1 = imageio.imread("12.png")
plt.imshow(im1)

# %% [markdown]
# In the restaurant industry, if someone says "location can make or break a restaurant", that would not be an exaggeration at all. One of the biggest, if not THE biggest, reasons that restaurants faill is poor location.

# %% [markdown]
# After a few meetings with the chef, I have decided that a good location for this acclaimed chef's new restaurant must exhibit the following characteristics: <br>
# <ul>
#     <li> User-friendly parking. It would be ideal that the restaurant has its own parking lot. </li>
#     <li> Accessibility. The restaurant is located off a major roadway. </li>
#     <li> Visibility. The restaurant can be easily seen from the streets. </li>
# </ul>

# %% [markdown]
# Those are the basic requirements. Based on the information that the chef will be openning a high-end culinary establishment that targets young and middle-aged diners with income in the higher range, it would be good busines acumen that the restaurant is located at where the target market lives, works and/or plays. In addition to user-friendly parking, accessibility and visibility, the location should also exhibit the following attributes: <br>
# <ul>
#     <li> Minimum population is preferably about 12,000 within a 5-mile radius. </li>
#     <li> Overall trade in the area is growing or stable. </li>
#     <li> Retail support is within one mile of site. </li>
#     <li> Ideal household income is $35,000 and above per year. </li>
#     <li> Unemployment rate in the area is less than 10% </li>
#     <li> Low crime rate. </li>
# </ul>

# %% [markdown]
# Other factors to consider are: <br>
# <ul>
#     <li> Saturation level in the area. Has the area been saturated by Asian restaurants? Does it have additional appetite for a high-end Asian restaurant? </li>
#     <li> Psychographics of the target market. For example, what would make them keep coming back? The pyschographics of target market tells the "why". </li>
# </ul>

# %% [markdown]
# Location. Location. Location. Good locations forebodes success. In this project, I will leverage the Foursquare location data as well as other data sources to scout the best location for this acclaimed chef's new high-end Asian restaurant.

# %% [markdown]
# ### II. Discriptions of the data and how it would be used to scout the best location:

# %% [markdown]
# #### A. Data analysis plan with Foursquare location data: description of the data and how it could be used to solve the problem at hand

# %% [markdown]
# 1. I will first define an instance of geocoder, get the latitude and longitude coordinates of the center of Toronto, then define a query to search on Foursquare API for Asian food that is located within 5 miles of the center of the location. This query will give me the addresses of the Asian restaurants within the radius. Sometimes, a restaurant is negatively viewed by diners not because of the food, service or ambience, but because restaurant businesses in that area had failed largedly in the past and customers had come to associate the area with "bad food". Hence, the first thing I am going to do is to search Foursquare and see where the popular and successful Asian restaurants are located. <br>
#
#
# 2. Define a query to get the ratings of the venues returned by the first query. This second query will tell me how diners regard the Asian restaurants in the area I am looking at and further narrow down where the popular Asian restaurants are located. This is psychographics. <br>
#
#
# 3. Define a third query to get the tips of the popular venues returned by the second query. As mentioned above, psychographics is a very important factor to consider when scouting a location for a new restaurant. This third query will give me a glimps of the pyschographics of diners who patroned the Asian restaurants in the area I am looking at. In addition, I might also be able to find out whether there is parking issue in this area, for example, has any Foursquare user complained about parking? <br>
#
#
# 4. Define a fourth query to explore the areas around the popular and successful Asian restaurants to find out what venues are trending in that area. This acclaimed chef is opening a high-end Asian restaurant that targets people with income in the higher range, for example, 35,000 USD and above annually. As mentioned above, it is good business acumen that the restaurant is located in where the target market lives, works and / or plays. This fourth query will give me the demographic information in the area I am looking at. For example, based on the trending venues returned, does it look like this is an area where young and middle-aged people with income at least 35,000 USD annually like to hang out? <br>

# %% [markdown]
# #### B. Data analysis plan with other data sources:

# %% [markdown]
# There are other questions related to scouting out the best location for a restaurant that Foursquare location data does not answer, for example, demographic questions such as population density, unemployment rate, crime rate, business growth. These are important factors to consider when scouting the best location for a new restaurant. <br>
#
# To answer these important demographic questions, I will leverage data from other sources such as:<br>
# <ul>
#     <li> The most recent census </li>
#     <li> Salary information from www.payscale.com </li>
#     <li> Internet search on Google about parking in Toronto. </li>
# </ul>

# %% [markdown]
# I will present three location choices to this acclaimed chef for his high-end Asian restaurant that will target young and middle-aged customers with income in the higher range, along with data, explanation and analysis on why these three locations stand out.
