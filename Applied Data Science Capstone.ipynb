# %% [markdown]
# # <center> Applied Data Science Capstone Porject: Battles of Neighborhoods <center>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
From IPython.display import Image
# Out:
#   File "<ipython-input-3-290692d8ce49>", line 1
#     From IPython.display import Image
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# For this capstone project, imagine that you live in the west side of the city of Toronto of Canada. You receive a job offer on the other side of the city with great career prospects. However, given the long distance from your current place, you must relocate if you accept the job offer. You would like to relocate to a neighborhood that is exactly the same as your current one, if not, at least to neighborhoods that are closer to your new job.

# %% [markdown]
# If this capstone project, you can compare different neighborhoods in terms of service, search for potential explanation of why a particular neighborhood is popular, or complaints in other neighborhood. Hence the name of the project will be Battles of Neighborhoods.

# %% [markdown]
# You will segment the city of Toronto into different neighborhoods, using the geographical coordinates of the center of each neighborhood, then using a combination of location data and machine learning, you will group the neighborhoods into clusters like the following:

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# There are many location data providers. As far as this capstone project is concerned, we will be usig the Foursquare location data set.

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# Example of location data:

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# Let's get started!

# %%
import pandas as pd
import numpy as np

# %%
print("Hello, capstone project course!")
# Out:
# Hello, capstone project course!
